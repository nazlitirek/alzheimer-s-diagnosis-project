# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('alzheimers_disease_data.csv')
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %% [markdown]
# Gender: Gender of the patients, where 0 represents Male and 1 represents Female.
# Ethnicity: The ethnicity of the patients, coded as follows:
# 0: Caucasian
# 1: African American
# 2: Asian
# 3: Other
# EducationLevel: The education level of the patients, coded as follows:
# 0: None
# 1: High School
# 2: Bachelor's
# 3: Higher
# AlcoholConsumption: Weekly alcohol consumption in units, ranging from 0 to 20.
# PhysicalActivity: Weekly physical activity in hours, ranging from 0 to 10.
#
#
# MMSE: Mini-Mental State Examination score, ranging from 0 to 30. Lower scores indicate cognitive impairment.
# FunctionalAssessment: Functional assessment score, ranging from 0 to 10. Lower scores indicate greater impairmen
# ADL: Activities of Daily Living score, ranging from 0 to 10. Lower scores indicate greater impairment.
#
# cite like this:
# @misc{rabie_el_kharoua_2024,
# title={Alzheimer's Disease Dataset},
# url={https://www.kaggle.com/dsv/8668279},
# DOI={10.34740/KAGGLE/DSV/8668279},
# publisher={Kaggle},
# author={Rabie El Kharoua},
# year={2024}
# }

# %%
df.describe().T
# Out:
#                             count         mean         std          min  \
# PatientID                  2149.0  5825.000000  620.507185  4751.000000
# Age                        2149.0    74.908795    8.990221    60.000000
# Gender                     2149.0     0.506282    0.500077     0.000000
# Ethnicity                  2149.0     0.697534    0.996128     0.000000
# EducationLevel             2149.0     1.286645    0.904527     0.000000
# BMI                        2149.0    27.655697    7.217438    15.008851
# Smoking                    2149.0     0.288506    0.453173     0.000000
# AlcoholConsumption         2149.0    10.039442    5.757910     0.002003
# PhysicalActivity           2149.0     4.920202    2.857191     0.003616
# DietQuality                2149.0     4.993138    2.909055     0.009385
# SleepQuality               2149.0     7.051081    1.763573     4.002629
# FamilyHistoryAlzheimers    2149.0     0.252210    0.434382     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
print(df.nunique())
# Out:
# PatientID                    2149
# Age                            31
# Gender                          2
# Ethnicity                       4
# EducationLevel                  4
# BMI                          2149
# Smoking                         2
# AlcoholConsumption           2149
# PhysicalActivity             2149
# DietQuality                  2149
# SleepQuality                 2149
# FamilyHistoryAlzheimers         2
# CardiovascularDisease           2
# Diabetes                        2
# Depression                      2
# HeadInjury                      2
# Hypertension                    2
# SystolicBP                     90
# DiastolicBP                    60
# CholesterolTotal             2149
# CholesterolLDL               2149
# CholesterolHDL               2149
# CholesterolTriglycerides     2149
# MMSE                         2149
# FunctionalAssessment         2149
# MemoryComplaints                2
# BehavioralProblems              2
# ...

# %%
print(df.isnull().sum())
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %%
for col in ['Gender', 'Ethnicity', 'EducationLevel', 'DoctorInCharge']:
    print(f"{col}: {df[col].unique()}")
# Out:
# Gender: [0 1]
# Ethnicity: [0 3 1 2]
# EducationLevel: [2 0 1 3]
# DoctorInCharge: ['XXXConfid']

# %%
df = df.drop(['PatientID', 'DoctorInCharge'], axis=1)

# %%
# Korelasyon matrisi
corr_matrix = df.corr(numeric_only=True)

# Isı haritası
plt.figure(figsize=(18, 15))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', center=0)
plt.title('Korelasyon Matrisi Isı Haritası', fontsize=16)
plt.show()

# %%
correlation_with_target = corr_matrix['Diagnosis'].sort_values(ascending=False)
print(correlation_with_target)
# Out:
# Diagnosis                    1.000000
# MemoryComplaints             0.306742
# BehavioralProblems           0.224350
# CholesterolHDL               0.042584
# Hypertension                 0.035080
# CardiovascularDisease        0.031490
# BMI                          0.026343
# CholesterolTriglycerides     0.022672
# DifficultyCompletingTasks    0.009069
# DietQuality                  0.008506
# CholesterolTotal             0.006394
# PhysicalActivity             0.005945
# DiastolicBP                  0.005293
# Forgetfulness               -0.000354
# Smoking                     -0.004865
# Age                         -0.005488
# Depression                  -0.005893
# AlcoholConsumption          -0.007618
# Ethnicity                   -0.014782
# SystolicBP                  -0.015615
# Confusion                   -0.019186
# PersonalityChanges          -0.020627
# Gender                      -0.020975
# HeadInjury                  -0.021411
# Disorientation              -0.024648
# ...

# %%
top_corr = correlation_with_target.drop('Diagnosis').abs().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')
plt.title("Diagnosis ile En Yüksek Korelasyona Sahip 10 Özellik", fontsize=14)
plt.xlabel("Korelasyon Katsayısı")
plt.ylabel("Özellik")
plt.show()
# Out:
# C:\Users\tirek\AppData\Local\Temp\ipykernel_20224\1949107694.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Forgetfulness', hue='Diagnosis', data=df, palette='Set2')

plt.title('Forgetfulness ve Diagnosis Arasındaki İlişki', fontsize=14)
plt.xlabel('Forgetfulness (0: Yok, 1: Var)', fontsize=12)
plt.ylabel('Kişi Sayısı', fontsize=12)
plt.legend(title='Diagnosis (0: Sağlıklı, 1: Alzheimer)')
plt.show()

# %%
hasta_sayisi = df[df['Diagnosis'] == 1].shape[0]
print(f"Verisetinde {hasta_sayisi} tane Alzheimer hastası var.")
saglikli_sayisi = df[df['Diagnosis'] == 0].shape[0]
print(f"Ayrıca {saglikli_sayisi} tane sağlıklı birey var.")
# Out:
# Verisetinde 760 tane Alzheimer hastası var.
# Ayrıca 1389 tane sağlıklı birey var.

# %%
df.to_csv("data.csv", index=False)
